# %%
# 대표적인 loss Function : Mean_Sqared_eror
# 손실 구하기

import matplotlib.pyplot as plt
x= [2,4,5,6]       # 공부한 시간
y = [81,93,91,97]  # 성적
# x독립변수, y종속변수
plt.figure(figsize=(8,5))
plt.scatter(x,y) # 산점도
plt.show()

ab=[5,76] # 가상의 기울기 a, y절편 b

# %%
# MSE 함수
def mse(y,y_hat):
    return((y-y_hat) **2).mean()

# 예측 함수
def perdict(x):
    return ab[0] * x+ab[1]

# 총 오차
def mse_val(y,result):
    return mse(np.array(y), np.array(result))

arr =[]
for i in range(len(x)):
    arr.append(perdict(x[i]))
    print(f"공부시간{x[i]}, 실제점수{y[i]}, 예측점수{predict(x[i])}")

# 최종 MSE
print("총 오차:",str(mse_val(arr,y)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 17
#      15 for i in range(len(x)):
#      16     arr.append(perdict(x[i]))
# ---> 17     print(f"공부시간{x[i]}, 실제점수{y[i]}, 예측점수{predict(x[i])}")
#      19 # 최종 MSE
#      20 print("총 오차:",str(mse_val(arr,y)))
#
# NameError: name 'predict' is not defined
